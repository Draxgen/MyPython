# %%
import pandas as pd

#print all columns when printing dataframes
pd.set_option('display.max_columns', None)

df = pd.read_csv('pokemon_data.csv')
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# 1         80       80     60           1      False
# 2        100      100     80           1      False
# 3        122      120     80           1      False
# 4         60       50     65           1      False
# ..       ...      ...    ...         ...        ...
# 795      100      150     50           6       True
# 796      160      110    110           6       True
# 797      150      130     70           6       True
# 798      170      130     80           6       True
# 799      130       90     70           6       True
#
# [800 rows x 12 columns]

# %%
##Reading Data
#print(df.head())

print(df.columns)

print(df[['Name', 'Type 1', 'HP']])

print(df.sort_values(['Type 1', 'HP'], ascending=[1,0]))
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')
#                       Name   Type 1  HP
# 0                Bulbasaur    Grass  45
# 1                  Ivysaur    Grass  60
# 2                 Venusaur    Grass  80
# 3    VenusaurMega Venusaur    Grass  80
# 4               Charmander     Fire  39
# ..                     ...      ...  ..
# 795                Diancie     Rock  50
# 796    DiancieMega Diancie     Rock  50
# 797    HoopaHoopa Confined  Psychic  80
# 798     HoopaHoopa Unbound  Psychic  80
# 799              Volcanion     Fire  80
#
# [800 rows x 3 columns]
#        #                     Name Type 1    Type 2  HP  Attack  Defense  \
# 520  469                  Yanmega    Bug    Flying  86      76       86
# 698  637                Volcarona    Bug      Fire  85      60       65
# 231  214                Heracross    Bug  Fighting  80     125       75
# 232  214  HeracrossMega Heracross    Bug  Fighting  80     185      115
# 678  617                 Accelgor    Bug       NaN  80      70       40
# ..   ...                      ...    ...       ...  ..     ...      ...
# 106   98                   Krabby  Water       NaN  30     105       90
# 125  116                   Horsea  Water       NaN  30      40       70
# 129  120                   Staryu  Water       NaN  30      45       55
# 139  129                 Magikarp  Water       NaN  20      10       55
# 381  349                   Feebas  Water       NaN  20      15       20
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 520      116       56     95           4      False
# 698      135      105    100           5      False
# 231       40       95     85           2      False
# 232       40      105     75           2      False
# 678      100       60    145           5      False
# ..       ...      ...    ...         ...        ...
# 106       25       25     50           1      False
# 125       70       25     60           1      False
# 129       70       55     85           1      False
# 139       15       20     80           1      False
# 381       10       55     80           3      False
#
# [800 rows x 12 columns]

# %%
##Change Data
#df['Total'] = df.iloc[:, 4:10].sum(axis=1)

df['Total'] = df.iloc[:, df.columns.get_loc('HP') : df.columns.get_loc('Generation')].sum(axis=1)

cols = list(df.columns.values)
df = df[cols[0:4] + [cols[-1]] + cols[4:12]]

#df.to_csv('modified.txt', index=False, sep='\t')

new_df

#new_df = new_df.reset_index()
# Out:
#        #                   Name Type 1  Type 2  Generation  Legendary  Total  \
# 2      3               Venusaur  Grass  Poison           1      False    525
# 3      3  VenusaurMega Venusaur  Grass  Poison           1      False    625
# 50    45              Vileplume  Grass  Poison           1      False    490
# 77    71             Victreebel  Grass  Poison           1      False    490
# 652  591              Amoonguss  Grass  Poison           5      False    464
#
#       HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# 2     80      82       83      100      100     80
# 3     80     100      123      122      120     80
# 50    75      80       85      110       90     50
# 77    80     105       65      100       70     70
# 652  114      85       70       85       80     30

# %%
new_df = df.loc[df['Type 1'] == 'Grass']

new_df
# Out:
#        #                   Name Type 1    Type 2  Speed  Generation  \
# 0      1              Bulbasaur  Grass    Poison     45           1
# 1      2                Ivysaur  Grass    Poison     60           1
# 2      3               Venusaur  Grass    Poison     80           1
# 3      3  VenusaurMega Venusaur  Grass    Poison     80           1
# 48    43                 Oddish  Grass    Poison     30           1
# ..   ...                    ...    ...       ...    ...         ...
# 718  650                Chespin  Grass       NaN     38           6
# 719  651              Quilladin  Grass       NaN     57           6
# 720  652             Chesnaught  Grass  Fighting     64           6
# 740  672                 Skiddo  Grass       NaN     52           6
# 741  673                 Gogoat  Grass       NaN     68           6
#
#      Legendary  Total   HP  Attack  Defense  Sp. Atk  Sp. Def
# 0        False    0.0   45      49       49       65       65
# 1        False    0.0   60      62       63       80       80
# 2        False    0.0   80      82       83      100      100
# 3        False    0.0   80     100      123      122      120
# 48       False    0.0   45      50       55       75       65
# ..         ...    ...  ...     ...      ...      ...      ...
# 718      False    0.0   56      61       65       48       45
# 719      False    0.0   61      78       95       56       58
# 720      False    0.0   88     107      122       74       75
# 740      False    0.0   66      65       48       62       57
# 741      False    0.0  123     100       62       97       81
#
# [70 rows x 13 columns]

# %%
new_df = df.iloc[0:5]

new_df
# Out:
#    #                   Name Type 1  Type 2  Speed  Generation  Legendary  \
# 0  1              Bulbasaur  Grass  Poison     45           1      False
# 1  2                Ivysaur  Grass  Poison     60           1      False
# 2  3               Venusaur  Grass  Poison     80           1      False
# 3  3  VenusaurMega Venusaur  Grass  Poison     80           1      False
# 4  4             Charmander   Fire     NaN     65           1      False
#
#    Total  HP  Attack  Defense  Sp. Atk  Sp. Def
# 0    0.0  45      49       49       65       65
# 1    0.0  60      62       63       80       80
# 2    0.0  80      82       83      100      100
# 3    0.0  80     100      123      122      120
# 4    0.0  39      52       43       60       50

# %%
new_df = df.loc[(df['Type 1'] == 'Grass') & (df['Type 2'] == 'Poison') & (df['HP']>70)]

new_df
# Out:
#        #                   Name Type 1  Type 2  Speed  Generation  Legendary  \
# 2      3               Venusaur  Grass  Poison     80           1      False
# 3      3  VenusaurMega Venusaur  Grass  Poison     80           1      False
# 50    45              Vileplume  Grass  Poison     50           1      False
# 77    71             Victreebel  Grass  Poison     70           1      False
# 652  591              Amoonguss  Grass  Poison     30           5      False
#
#      Total   HP  Attack  Defense  Sp. Atk  Sp. Def
# 2      0.0   80      82       83      100      100
# 3      0.0   80     100      123      122      120
# 50     0.0   75      80       85      110       90
# 77     0.0   80     105       65      100       70
# 652    0.0  114      85       70       85       80
